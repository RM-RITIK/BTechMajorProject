# %%
import pandas as pd
df = pd.read_csv ('BIO_tagged_dataset_TextRank.csv')

# %%
df.head()
# Out:
#                                                 text  \
# 0  several inorganic flocculating agents includin...
# 1  video oculography is one of eye movement measu...
# 2  the first principles calculations are performe...
# 3  microhardness can be related to other macrosco...
# 4  we consider finite time future or big rip sing...
#
#                                           BIO_tag_TR  \
# 0  O O O O O O O O O B I I I O O O O O B O B I O ...
# 1  B I O O O B I O O O O O O O O O O O O B O O B ...
# 2  O O O O O O O O B I I I I O O O B O B I O O B ...
# 3  B O O O O O O O O O O B I O B I O O O B I O B ...
# 4  O O B I I O O O O O O O O O B I I O O O O B O ...
#
#                                             keywords  \
# 0  ['Al2(SO4)3,', 'analyzes the main factors', 'C...
# 1  ['accurately estimate the pupil center', 'Cann...
# 2  ['Al', 'alloy', 'Brillouin-zone sampling', 'Ca...
# 3  ['compression testing', 'derived a direct prop...
# ...

# %%
x=df.iloc[0]['text'].split()

# %%
len(x)
# Out:
# 90

# %%
y=df.iloc[0]['BIO_tag_TR'].split()

# %%
len(y)
# Out:
# 90

# %%
z=df.iloc[0]['BIO_tag'].split()

# %%
len(z)
# Out:
# 90

# %%
print(z)
# Out:
# ['O', 'B', 'I', 'I', 'O', 'B', 'B', 'O', 'O', 'B', 'I', 'I', 'B', 'O', 'O', 'O', 'B', 'I', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'I', 'I', 'O', 'B', 'I', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'I', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'I', 'I', 'I', 'O', 'O', 'B', 'I', 'O']

# %%
count=0
for i in  range(len(y)):
    if z[i] == y[i]:
        count=count+1

# %%
count
# Out:
# 66

# %%
def positives(y, z):
    count=0
    for i in  range(len(y)):
        if(len(z)!=len(y)):
            print("Length miss match")
        elif z[i] == y[i]:
            print("Here")
            count=count+1
    return count

# %%
def accuracy():
    total=0
    total_accurate=0
    for i in range(len(df)):
        y=df.iloc[i]['BIO_tag_TR'].split()
        z=df.iloc[i]['BIO_tag'].split()
        total=total+len(y)
        total_accurate=total_accurate+positives(y, z)
    print(total)
    print(total_accurate)
    ans=total_accurate/total
    return ans

# %%
accuracy()
# Out:
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# ...

# %%
total
# Out:
# 0
